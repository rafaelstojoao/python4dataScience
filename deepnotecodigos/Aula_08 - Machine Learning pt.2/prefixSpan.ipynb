# %%
# !pip install prefixspan
from prefixspan import PrefixSpan

dataset = [
    [0, 1, 2, 3, 4],
    [1, 1, 1, 3, 4],
    [2, 1, 2, 2, 0],
    [1, 1, 1, 2, 2],
]


ds = [['pão','muçarela','presunto'],
               ['pão','muçarela','presunto','mortadela', 'leite'],
               ['pão','muçarela','mortadela'],
               ['pão','presunto','mortadela','leite'],
               ['pão','muçarela','presunto','mortadela'],
               ['mortadela','pão'],
               ['ovo','leite']]

modeloPrefixSpan = PrefixSpan(ds)
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: prefixspan in /opt/venv/lib/python3.7/site-packages (0.5.2)
# Requirement already satisfied: extratools>=0.8.1 in /opt/venv/lib/python3.7/site-packages (from prefixspan) (0.8.2.1)
# Requirement already satisfied: docopt>=0.6.2 in /opt/venv/lib/python3.7/site-packages (from prefixspan) (0.6.2)
# Requirement already satisfied: toolz>=0.9.0 in /opt/venv/lib/python3.7/site-packages (from extratools>=0.8.1->prefixspan) (0.11.1)
# Requirement already satisfied: sortedcontainers>=1.5.10 in /opt/venv/lib/python3.7/site-packages (from extratools>=0.8.1->prefixspan) (2.3.0)
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
for frequente in modeloPrefixSpan.frequent(3):
    print(frequente)
# Out:
# (6, ['pão'])
# (4, ['pão', 'muçarela'])
# (3, ['pão', 'muçarela', 'presunto'])
# (3, ['pão', 'muçarela', 'mortadela'])
# (4, ['pão', 'presunto'])
# (3, ['pão', 'presunto', 'mortadela'])
# (4, ['pão', 'mortadela'])
# (4, ['muçarela'])
# (3, ['muçarela', 'presunto'])
# (3, ['muçarela', 'mortadela'])
# (4, ['presunto'])
# (3, ['presunto', 'mortadela'])
# (5, ['mortadela'])
# (3, ['leite'])
